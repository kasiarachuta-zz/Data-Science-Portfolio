# %% [markdown]
# # Titanic - Predicting Survival Exploratory Data Analysis
# *Katarzyna O Rachuta, last updated 2017-07-09*
#
# ## Background
# The sinking of RMS Titanic happened on the 15th April 1912, killing 1502 out of 2224 that were on board. It is known that some (such as upper middle class, women or children) were more likely to survive than others. This analysis explores the dataset, providing background for further modeling and prediction of survival.
#
#
# ## Method
# Exploring factor such as:<br>
# a) Passenger class (Pclass), which is also a proxy for their socio-economic class<br>
# b) Sex <br>
# c) Age <br>
# d) Point of emabrkment
#
# ## References
# [Kaggle](https://www.kaggle.com/c/titanic), accessed 2016-01-04

# %%
# Importing useful modules
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
# Visuals
from bokeh.plotting import *
output_notebook()
from bokeh.charts import BoxPlot, show, defaults, Histogram, Bar
from bokeh.layouts import row, column
# Out:
# /Users/kasia/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="24ef3c00-ca64-438f-85f8-a0a50d4d8dbc">Loading BokehJS ...</span>
#     </div>

# %%
# Reading the train data and displaying the first 5 rows.
train = pd.read_csv("train.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Viewing different types of objects.
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Exploratory Visuals
# Proportion of passengers that have survived by different categories

# %% [markdown]
# ## Class by survival

# %%
# Creating a smaller DataFrame
survival = train[['Survived', 'Pclass']]

p = Bar(train, label='Pclass', values='Pclass', group='Survived', plot_width=450, plot_height=450,
       tools = False)
p.title.text = 'Most casualties were from 3rd class'
p.yaxis.axis_label = 'Number of casualties'
p.xaxis.axis_label = 'Class by survival'

# Removing grid lines
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="01ec84df-9588-4237-bc93-fefd4b0b8472"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("01ec84df-9588-4237-bc93-fefd4b0b8472");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01ec84df-9588-4237-bc93-fefd4b0b8472");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01ec84df-9588-4237-bc93-fefd4b0b8472' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"48e7c85a-83a5-49e4-8099-ac6ea5b46121":{"roots":{"references":[{"attributes":{"data_source":{"id":"c4fb3fdf-52d5-4184-b449-753880a69370","type":"ColumnDataSource"},"glyph":{"id":"63c3d21c-b5bf-4416-9737-854405d97d58","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e1835c43-fc5e-44ab-9c4e-582eef904c30","type":"GlyphRenderer"},{"attributes":{},"id":"1e1a766e-0589-4152-9237-0842f76e2bab","type":"BasicTicker"},{"attributes":{"items":[{"id":"cf465fff-c243-4d5a-a934-f5784a7d51f6","type":"LegendItem"},{"id":"b270fccc-ba45-4fae-bc20-714b8f955930","type":"LegendItem"}],"location":"top_left","plot":{"id":"d8673a19-6561-47b7-a227-825260169fc0","subtype":"Chart","type":"Plot"}},"id":"1a8518b8-7042-4642-969a-6ec051d050d7","type":"Legend"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"d8673a19-6561-47b7-a227-825260169fc0","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e1a766e-0589-4152-9237-0842f76e2bab","type":"BasicTicker"}},"id":"0dc23155-f46d-4a9c-9d0c-c58a3d594bdd","type":"Grid"},{"attributes":{"axis_label":"Number of casualties","formatter":{"id":"80407f98-f2c7-49ee-8169-6d85fa004d17","type":"BasicTickFormatter"},"plot":{"id":"d8673a19-6561-47b7-a227-825260169fc0","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e1a766e-0589-4152-9237-0842f76e2bab","type":"BasicTicker"}},"id":"e097ed0b-3e33-4881-a2db-8b3dbaffafa9","type":"LinearAxis"},{"attributes":{},"id":"a64c2d0a-5482-44f3-adcf-d8fc669c161d","type":"ToolEvents"},{"attributes":{"axis_label":"Class by survival","formatter":{"id":"b6b4c1c8-1f33-40f2-81a4-e4dc3ce20f96","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"d8673a19-6561-47b7-a227-825260169fc0","subtype":"Chart","type":"Plot"},"ticker":{"id":"c18194ff-b3fa-40aa-925f-5ecb3d0d901e","type":"CategoricalTicker"}},"id":"db7003f3-c095-4668-94de-e36eaa2b17b2","type":"CategoricalAxis"},{"attributes":{"callback":null,"end":1171.8},"id":"a9e083cf-ac61-4dfb-90d9-a8bd68f96a9a","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Pclass":[1],"Survived":[1],"chart_index":[{"Pclass":1,"Survived":1}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[136.0],"label":[{"Pclass":1,"Survived":1}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["1:0.666666666667"],"y":[68.0]}},"id":"5dc5152b-c61f-496e-8b59-9f57e5b8174f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5dc5152b-c61f-496e-8b59-9f57e5b8174f","type":"ColumnDataSource"},"glyph":{"id":"b404822a-ee18-42d4-af56-153691988cab","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f648ca91-bf96-4ff4-812e-82f6f49c2e27","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Pclass":[1],"Survived":[0],"chart_index":[{"Pclass":1,"Survived":0}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[80.0],"label":[{"Pclass":1,"Survived":0}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["1:0.333333333333"],"y":[40.0]}},"id":"0b4ac9f4-2049-4f3b-ac01-f15bc69f09da","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Pclass":[3],"Survived":[0],"chart_index":[{"Pclass":3,"Survived":0}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1116.0],"label":[{"Pclass":3,"Survived":0}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["3:0.333333333333"],"y":[558.0]}},"id":"882b0ccb-97f7-4288-81f1-a23b3715c3a0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"882b0ccb-97f7-4288-81f1-a23b3715c3a0","type":"ColumnDataSource"},"glyph":{"id":"082b8d58-a2e1-487e-9fa4-a98d45e7abcd","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8415d903-a971-4f60-a138-c008dfb236d0","type":"GlyphRenderer"},{"attributes":{"below" ...

# %% [markdown]
# ## Sex by survival

# %%
p = Bar(train, label='Sex', group='Survived', plot_width=450, plot_height=450,
       tools = False)
p.title.text = 'Most casualties were male'
p.yaxis.axis_label = 'Number of casualties'
p.xaxis.axis_label = 'Sex by survival'

# Removing grid lines
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="64a42051-d756-4cc6-b7a8-51d4762710f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("64a42051-d756-4cc6-b7a8-51d4762710f1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("64a42051-d756-4cc6-b7a8-51d4762710f1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '64a42051-d756-4cc6-b7a8-51d4762710f1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"028f73ab-4954-449b-9233-68f66f43d047":{"roots":{"references":[{"attributes":{},"id":"e9a4ebcc-634a-44c1-9da4-985e0246d000","type":"CategoricalTickFormatter"},{"attributes":{"below":[{"id":"6b594b0b-7b6b-40be-bd3b-0e152f39154a","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"7f271e29-3622-4d1c-92b1-84cf16317c47","type":"LinearAxis"}],"plot_height":450,"plot_width":450,"renderers":[{"id":"6723eef4-d202-4b43-b5d1-c7ee9f914787","type":"GlyphRenderer"},{"id":"39300f2a-f630-4d0e-b9a1-808c7a5f7494","type":"GlyphRenderer"},{"id":"2002db20-7802-462c-bb43-9bdb3e802f1b","type":"GlyphRenderer"},{"id":"abeaeb1b-3813-4570-97ac-d3f8d6958514","type":"GlyphRenderer"},{"id":"6b6f0118-e772-4432-92e1-424a9f52300d","type":"Legend"},{"id":"6b594b0b-7b6b-40be-bd3b-0e152f39154a","type":"CategoricalAxis"},{"id":"7f271e29-3622-4d1c-92b1-84cf16317c47","type":"LinearAxis"},{"id":"a4438010-36a7-4809-b81b-13a9e7392391","type":"Grid"}],"title":{"id":"3a458d09-bd01-4f06-9f04-4c39b0805dea","type":"Title"},"tool_events":{"id":"acedfcf6-1a9f-47b5-82c0-af23436db9da","type":"ToolEvents"},"toolbar":{"id":"26eb87e8-adf7-4132-b6ca-b5535c22dd9d","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"68b03f34-271f-4cda-bfd1-9fcc4e98c573","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"29d74bf7-196e-43b2-a7c5-3790519b11ac","type":"Range1d"}},"id":"53697ac5-ddab-4e0c-928f-7aab4e4c1849","subtype":"Chart","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto"},"id":"26eb87e8-adf7-4132-b6ca-b5535c22dd9d","type":"Toolbar"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"6723eef4-d202-4b43-b5d1-c7ee9f914787","type":"GlyphRenderer"}]},"id":"a23173de-1740-48a0-babc-1851a6e0bbc0","type":"LegendItem"},{"attributes":{},"id":"f6d99fac-4b68-48c6-8e2e-aa91471d7015","type":"CategoricalTicker"},{"attributes":{"callback":null,"end":491.4},"id":"29d74bf7-196e-43b2-a7c5-3790519b11ac","type":"Range1d"},{"attributes":{},"id":"acedfcf6-1a9f-47b5-82c0-af23436db9da","type":"ToolEvents"},{"attributes":{"axis_label":"Sex by survival","formatter":{"id":"e9a4ebcc-634a-44c1-9da4-985e0246d000","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"53697ac5-ddab-4e0c-928f-7aab4e4c1849","subtype":"Chart","type":"Plot"},"ticker":{"id":"f6d99fac-4b68-48c6-8e2e-aa91471d7015","type":"CategoricalTicker"}},"id":"6b594b0b-7b6b-40be-bd3b-0e152f39154a","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Sex":["female"],"Survived":[1],"chart_index":[{"Sex":"female","Survived":1}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[233.0],"label":[{"Sex":"female","Survived":1}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["female:0.666666666667"],"y":[116.5]}},"id":"d9779396-eb1b-439d-8472-b673ca34a2cc","type":"ColumnDataSource"},{"attributes":{"axis_label":"Number of casualties","formatter":{"id":"a422f2da-6c43-4516-91ff-d2b87492a611","type":"BasicTickFormatter"},"plot":{"id":"53697ac5-ddab-4e0c-928f-7aab4e4c1849","subtype":"Chart","type":"Plot"},"ticker":{"id":"e3733a91-51d9-46ea-910c-0720478f6d55","type":"BasicTicker"}},"id":"7f271e29-3622-4d1c-92b1-84cf16317c47","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"327ad0c8-6f3f-448c-9e2d-f599d609e290","type":"Rect"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"53697ac5-ddab-4e0c-928f-7aab4e4c1849","subtype":"Chart","type":"Plot"},"ticker":{"id":"e3733a91-51d9-46ea-910c-0720478f6d55","type":"BasicTicker"}},"id":"a4438010-36a7-4809-b81b-13a9e7392391","type":"Grid"},{"attributes":{"data_source":{"id":"f6a2106d-8102-4c8e-8e9c-6a52fee1e322","type":"ColumnDa ...

# %% [markdown]
# ## Survival by point of embarkment

# %%
embarked_df = train[['Embarked', 'Survived']].dropna()

p = Bar(embarked_df, label='Embarked', group='Survived', plot_width=450, plot_height=450,
       tools = False)
p.title.text = 'Most casualties embarked in Southampton'
p.yaxis.axis_label = 'Number of casualties'
p.xaxis.axis_label = 'Embarkation point by survival'

# Removing grid lines
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="546369e9-8280-4bf8-bc53-43b49d1205e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("546369e9-8280-4bf8-bc53-43b49d1205e6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("546369e9-8280-4bf8-bc53-43b49d1205e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '546369e9-8280-4bf8-bc53-43b49d1205e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eb946b55-13ad-43b8-8a32-f4a361a569e9":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Embarked":["C"],"Survived":[0],"chart_index":[{"Embarked":"C","Survived":0}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[75.0],"label":[{"Embarked":"C","Survived":0}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["C:0.333333333333"],"y":[37.5]}},"id":"57e91be8-1cf3-4fc4-a06d-31707efe1c69","type":"ColumnDataSource"},{"attributes":{},"id":"631e4fc1-1724-4944-a617-5eb44d57a246","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc2fca19-83dd-4a7d-a77d-ce4ee5f4cadc","type":"Rect"},{"attributes":{"items":[{"id":"b548931b-e684-40da-bda3-3fc3096a2a5d","type":"LegendItem"},{"id":"a1c2095e-dda5-4ceb-9c25-7c131cbf5394","type":"LegendItem"}],"location":"top_left","plot":{"id":"13c5a87e-6d20-4f4d-a0a1-fcd8916961a9","subtype":"Chart","type":"Plot"}},"id":"3dd9f14d-d43f-460d-90f8-8b1055f436e4","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"720be940-91d4-4706-b94c-17e414c2b3aa","type":"Rect"},{"attributes":{"data_source":{"id":"77990953-feb6-45ba-a3f7-f1e7b0cac8d0","type":"ColumnDataSource"},"glyph":{"id":"eb6a3d0c-85e8-43a3-8373-e5d952cc186f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"70821761-0e17-40b9-97ae-520d3fa2335b","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":448.35},"id":"4328181f-d099-41e7-9abe-62b7c87fe0ec","type":"Range1d"},{"attributes":{},"id":"35cff900-c124-42d1-b5dd-5bb9a6846725","type":"CategoricalTicker"},{"attributes":{"label":{"value":"1"},"renderers":[{"id":"76344efc-22ee-4f10-b5ff-ce3253e7e517","type":"GlyphRenderer"}]},"id":"a1c2095e-dda5-4ceb-9c25-7c131cbf5394","type":"LegendItem"},{"attributes":{"data_source":{"id":"c1f1f4c4-7f08-4003-953c-7e7ebd57275a","type":"ColumnDataSource"},"glyph":{"id":"0efd3e76-f0ef-41b9-8ee8-08c7917a26e7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"76344efc-22ee-4f10-b5ff-ce3253e7e517","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"Embarked":["S"],"Survived":[1],"chart_index":[{"Embarked":"S","Survived":1}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[217.0],"label":[{"Embarked":"S","Survived":1}],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["S:0.666666666667"],"y":[108.5]}},"id":"37d6901a-ac73-40ed-bb29-265302f64c76","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"040005a3-755e-421e-9bd7-011538c687cb","type":"ColumnDataSource"},"glyph":{"id":"31f4a228-67a7-4c91-8489-91132ffcdfe5","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"233769e0-ef45-43a3-8120-f0d6bb501a44","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"299c1305-5e94-47c4-930e-a2265d065dc2","type":"Rect"},{"attributes":{},"id":"ccad3262-9580-487d-b349-c87d8de969db","type":"ToolEvents"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"13c5a87e-6d20-4f4d-a0a1-fcd8916961a9","subtype":"Chart","type":"Plot"},"ticker":{"id":"631e4fc1-1724-4944-a617-5eb44d57a246","type":"BasicTicker"}},"id":"0a718750-69c1-4f75-949e-cc35049a3d39","type":"Grid"},{"attributes":{"axis_label":"Number of casualties","formatter":{"id":"27d9a24a-4 ...

# %% [markdown]
# ## Age by survival

# %%
age_df = train[['Age', 'Survived']].dropna()

survived = age_df[age_df['Survived'] == 1]
deceased = age_df[age_df['Survived'] == 0 ]

p1 = Histogram(survived, values='Age', plot_width=450, plot_height=450, fill_alpha=0.3, outline_line_alpha=0, 
              line_color='white',  notebook=True, tools=False, color='grey')

p1.yaxis.axis_label = 'Passenger count'
p1.xaxis.axis_label = 'Age'
p1.title.text = 'Mean deceased passenger age is 30'

# removing grid lines
p1.xgrid.grid_line_color = None
p1.ygrid.grid_line_color = None

for r in p1.renderers:
    try:
        r.glyph.line_color = None
        r.glyph.line_alpha = r.glyph.fill_alpha
    except:
        pass

x1 = survived.median()
x2 = survived.mean()
y = (0, 6000)

p1.line(x1, y, legend='Median', line_width=1, color='#F8A800')
p1.line(x2, y, color='red', legend='Mean', line_width=1)

p1.legend.location = 'top_right'


p2 = Histogram(deceased, values='Age', plot_width=450, plot_height=450, fill_alpha=0.3, outline_line_alpha=0, 
              line_color='white',  notebook=True, tools=False, color='grey')

p2.yaxis.axis_label = 'Passenger count'
p2.xaxis.axis_label = 'Age'
p2.title.text = 'Mean/median age of a survived passenger is 28'

# removing grid lines
p2.xgrid.grid_line_color = None
p2.ygrid.grid_line_color = None

for r in p2.renderers:
    try:
        r.glyph.line_color = None
        r.glyph.line_alpha = r.glyph.fill_alpha
    except:
        pass

x3 = deceased.median()
x4 = deceased.mean()
y = (0, 6000)

p2.line(x3, y, legend='Median', line_width=1, color='#F8A800')
p2.line(x4, y, color='red', legend='Mean', line_width=1)

p2.legend.location = 'top_right'


show(row(p1, p2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b2203f54-d800-4312-8a9e-0da46413bedb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b2203f54-d800-4312-8a9e-0da46413bedb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b2203f54-d800-4312-8a9e-0da46413bedb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b2203f54-d800-4312-8a9e-0da46413bedb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c7eab1f-b145-40cf-8358-5f2dcb0ab128":{"roots":{"references":[{"attributes":{"data_source":{"id":"e4ef2126-5437-4353-94f6-faed7b332dca","type":"ColumnDataSource"},"glyph":{"id":"475a4d7c-4c27-4c2f-8d05-814dbb0f9d03","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0f2e7452-6a12-434f-9bc7-0020e6eeaf8f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_alpha":{"field":"fill_alpha"},"line_color":{"value":null},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1858d945-ed58-4d29-a1bf-eae71711b74d","type":"Rect"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto"},"id":"d92a3af2-b36d-4ec5-85e2-f9e74d76c47c","type":"Toolbar"},{"attributes":{"data_source":{"id":"4ff78dff-2874-4477-8ec8-af525efd7d07","type":"ColumnDataSource"},"glyph":{"id":"41e0d7a5-062b-4b98-b80e-40191e4a97a2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"27287ba3-4838-4696-b238-94aae550640e","type":"Line"},"selection_glyph":null},"id":"8b9b9f05-b299-4302-9e99-dd2def8b26fc","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(46.625000, 51.187500]"],"color":["grey"],"fill_alpha":[0.3],"height":[23.0],"label":["(46.625000, 51.187500]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["48.90625"],"y":[11.5]}},"id":"0381060f-84e6-43af-a0f7-80f189a0a224","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_alpha":{"field":"fill_alpha"},"line_color":{"value":null},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"11ab849b-4de7-4cbd-923e-185a14012ebc","type":"Rect"},{"attributes":{"label":{"value":"Mean"},"renderers":[{"id":"33670f41-7335-472e-bcf4-2875e8b7c3ca","type":"GlyphRenderer"}]},"id":"59b66499-5ead-4d09-bc9d-e6ab2ac4d591","type":"LegendItem"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"535ac394-6826-44cf-9ffb-cf941bc8732e","type":"Line"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_alpha":{"field":"fill_alpha"},"line_color":{"value":null},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6761c284-7896-48d2-8115-bbade54a898c","type":"Rect"},{"attributes":{},"id":"ce7fecc9-2742-4fc2-8c50-5c25e726fa55","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":82.0105,"start":-1.5905},"id":"91e964c0-27c0-470d-accb-1fb174c65a00","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(32.937500, 37.500000]"],"color":["grey"],"fill_alpha":[0.3],"height":[43.0],"label":["(32.937500, 37.500000]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["35.21875"],"y":[21.5]}},"id":"3940c125-9573-483a-936c-c440cf57c0f9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_alpha":{"field":"fill_alpha"},"line_color":{"value":null},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9b6e240a-ce2d-4e74-906d-5e47727d6cbe","type":"Rect"},{"attributes":{"axis_label":"Age","formatter":{"id":"9030d20a-7994-48de-a044-cacb2d272a81","type":"BasicTickFormatter"},"plot":{"id":"dc5c30e3-1a2b-4963-b90f-2baf98996887","subtype":"Chart","type":"Plot"},"ticker":{"id":"9120f696-7bc0-44a5-ae96-5212c2ed9ebb","type":"BasicTicker"}},"id":"e11d6c72-27f8-4700-ba0e-384c17029fd2","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field": ...

# %% [markdown]
# ## Logistic Regression - Classification
#
# Classificaiton will be based on their class, sex, age and embarkment point.
#
# ### Logistic Regression using sklearn

# %% [markdown]
# #### Step 1: Dummifying categorical variables.
# Categorical variables include Pclass, sex and embarkment point.

# %%
# Getting dummies

Pclass_dummies = pd.get_dummies(train['Pclass'])
sex_dummies = pd.get_dummies(train['Sex'])
embarked_dummies = pd.get_dummies(train['Embarked'])

# Dropping one dummy variable from each categorical variable to avoid collinearity.

Pclass_dummies = Pclass_dummies.drop(1, axis=1)
sex_dummies = sex_dummies.drop('male', axis=1)
embarked_dummies = embarked_dummies.drop('S', axis=1)

# Joining all the dummy variables back together.

dummies = Pclass_dummies.join(sex_dummies)
dummies = dummies.join(embarked_dummies)

# Making sure I've joined the right variables.
dummies.head()
# Out:
#    2  3  female  C  Q
# 0  0  1       0  0  0
# 1  0  0       1  1  0
# 2  0  1       1  0  0
# 3  0  0       1  0  0
# 4  0  1       0  0  0

# %%
# Adding the age variable to the dummy.

X_multi = dummies.join(train['Age'])
X_multi.head()
# Out:
#    2  3  female  C  Q   Age
# 0  0  1       0  0  0  22.0
# 1  0  0       1  1  0  38.0
# 2  0  1       1  0  0  26.0
# 3  0  0       1  0  0  35.0
# 4  0  1       0  0  0  35.0

# %%
# Checking where null variables occur.

X_multi['Age'] = X_multi['Age'].fillna(0)
X_multi.dtypes
# Out:
# 2           uint8
# 3           uint8
# female      uint8
# C           uint8
# Q           uint8
# Age       float64
# dtype: object

# %%
Y = train['Survived']
Y = np.ravel(Y)

# %%
log_reg = LogisticRegression()

# %%
# Fitting the logistic regression model to my data.

log_reg.fit(X_multi, Y)

# Printing the accuracy score for my model.

log_reg.score(X_multi, Y)
# Out:
# 0.78900112233445563

# %% [markdown]
# The model accuracy is ~79% accurate. This isn't terrible.

# %%
1 - Y.mean()
# Out:
# 0.61616161616161613

# %%
# Viewing the coefficients for each variable.

coeff_df = pd.DataFrame(zip(X_multi.columns,np.transpose(log_reg.coef_)))
coeff_df
# Out:
#         0                   1
# 0       2   [-0.664318000581]
# 1       3    [-1.92427966605]
# 2  female     [2.50448202773]
# 3       C    [0.524951027223]
# 4       Q     [0.26239071826]
# 5     Age  [-0.0134319512334]

# %% [markdown]
# From the coefficients above, we see that being a female has the strongest correlation with survival and being in third class is correlated with not surviving.

# %% [markdown]
# ### Logistic regression using statsmodels

# %%
data2 = X_multi.join(train['Survived'])
data2 = sm.add_constant(data2, prepend=False)
explanatory_cols = [2, 3, 'female', 'C', 'Q', 'Age', 'const']
full_logit_model = sm.GLM(data2['Survived'], 
                          data2[explanatory_cols], 
                          family=sm.families.Binomial())
result = full_logit_model.fit()
# Printing the summary of the results.
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  891
# Model:                            GLM   Df Residuals:                      884
# Model Family:                Binomial   Df Model:                            6
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -405.96
# Date:                Sun, 09 Jul 2017   Deviance:                       811.91
# Time:                        21:19:48   Pearson chi2:                     931.
# No. Iterations:                     5
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 2             -0.7730      0.256     -3.016      0.003      -1.275      -0.271
# 3             -2.0749      0.243     -8.524      0.000      -2.552      -1.598
# female         2.6123      0.186     14.018      0.000       2.247       2.978
# C              0.5320      0.230      2.313      0.021       0.081       0.983
# Q              0.2994      0.323      0.927      0.354      -0.334       0.932
# Age           -0.0143      0.005     -2.643      0.008      -0.025      -0.004
# const         -0.0548      0.267     -0.205      0.837      -0.578       0.469
# ==============================================================================
# """
